# %%
import torch
from datasets import load_dataset
from transformers import (
    ViTImageProcessor,
    ViTForImageClassification,
    TrainingArguments,
    Trainer
)

# %%
dataset = load_dataset(
    "imagefolder",
    data_dir=r"C:\Users\praut\project crop doctor\Rice"
)

print(dataset)
# Out:
# Resolving data files:   0%|          | 0/4078 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 4078
#     })
# })

# %%
dataset = dataset["train"].train_test_split(
    test_size=0.2,
    seed=42,
    stratify_by_column="label"
)

print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 3262
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 816
#     })
# })

# %%
labels = dataset["train"].features["label"].names

id2label = {i: label for i, label in enumerate(labels)}
label2id = {label: i for i, label in enumerate(labels)}

print(labels)
# Out:
# ['Rice___Brown_Spot', 'Rice___Healthy', 'Rice___Leaf_Blast', 'Rice___Neck_Blast']

# %%
from transformers import ViTImageProcessor

model_name = "google/vit-base-patch16-224-in21k"

processor = ViTImageProcessor.from_pretrained(
    "./corn-vit-final"
)
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.10-64\lib\site-packages\transformers\utils\hub.py:437, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     435 if len(full_filenames) == 1:
#     436     # This is slightly better for only 1 file
# --> 437     hf_hub_download(
#     438         path_or_repo_id,
#     439         filenames[0],
#     440         subfolder=None if len(subfolder) == 0 else subfolder,
#     441         repo_type=repo_type,
#     442         revision=revision,
#     443         cache_dir=cache_dir,
#     444         user_agent=user_agent,
#     445         force_download=force_download,
#     446         proxies=proxies,
#     447         token=token,
#     448         local_files_only=local_files_only,
#     449         tqdm_class=tqdm_class,
#     450     )
#     451 else:
#
# File ~\AppData\Local\Python\pythoncore-3.10-64\lib\site-packages\huggingface_hub\utils\_validators.py:84, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      83     if arg_name in ["repo_id", "from_id", "to_id"]:
# ---> 84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.10-64\lib\site-packages\huggingface_hub\utils\_validators.py:138, in validate_repo_id(repo_id)
#     137 if not REPO_ID_REGEX.match(repo_id):
# --> 138     raise HFValidationError(
#     139         "Repo id must use alphanumeric chars, '-', '_' or '.'."
#     140         " The name cannot start or end with '-' or '.' and the maximum length is 96:"
#     141         f" '{repo_id}'."
#     142     )
#     144 if "--" in repo_id or ".." in repo_id:
#
# HFValidationError: Repo id must use alphanumeric chars, '-', '_' or '.'. The name cannot start or end with '-' or '.' and the maximum length is 96: './corn-vit-final'.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 5
#       1 from transformers import ViTImageProcessor
#       3 model_name = "google/vit-base-patch16-224-in21k"
# ----> 5 processor = ViTImageProcessor.from_pretrained(
#       6     "./corn-vit-final"
#       7 )
#
# File ~\AppData\Local\Python\pythoncore-3.10-64\lib\site-packages\transformers\image_processing_base.py:179, in ImageProcessingMixin.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, **kwargs)
#     176 if token is not None:
#     177     kwargs["token"] = token
# --> 179 image_processor_dict, kwargs = cls.get_image_processor_dict(pretrained_model_name_or_path, **kwargs)
#     181 return cls.from_dict(image_processor_dict, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.10-64\lib\site-packages\transformers\image_processing_base.py:282, in ImageProcessingMixin.get_image_processor_dict(cls, pretrained_model_name_or_path, **kwargs)
#     280 image_processor_file = image_processor_filename
#     281 try:
# --> 282     resolved_processor_file = cached_file(
#     283         pretrained_model_name_or_path,
#     284         filename=PROCESSOR_NAME,
#     285         cache_dir=cache_dir,
#     286         force_download=force_download,
#     287         proxies=proxies,
#     288         local_files_only=local_files_only,
#     289         token=token,
#     290         user_agent=user_agent,
#     291         revision=revision,
#     292         subfolder=subfolder,
#     293         _raise_exceptions_for_missing_entries=False,
#     294     )
#     295     resolved_image_processor_file = cached_file(
#     296         pretrained_model_name_or_path,
#     297         filename=image_processor_file,
#    (...)
#     306         _raise_exceptions_for_missing_entries=False,
#     307     )
#     308 except OSError:
#     309     # Raise any environment error raise by `cached_file`. It will have a helpful error message adapted to
#     310     # the original exception.
#
# File ~\AppData\Local\Python\pythoncore-3.10-64\lib\site-packages\transformers\utils\hub.py:293, in cached_file(path_or_repo_id, filename, **kwargs)
#     238 def cached_file(
#     239     path_or_repo_id: str | os.PathLike,
#     240     filename: str,
#     241     **kwargs,
#     242 ) -> str | None:
#     243     """
#     244     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     245
#    (...)
#     291     ```
#     292     """
# --> 293     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     294     file = file[0] if file is not None else file
#     295     return file
#
# File ~\AppData\Local\Python\pythoncore-3.10-64\lib\site-packages\transformers\utils\hub.py:488, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     482     raise OSError(
#     483         f"PermissionError at {e.filename} when downloading {path_or_repo_id}. "
#     484         "Check cache directory permissions. Common causes: 1) another user is downloading the same model (please wait); "
#     485         "2) a previous download was canceled and the lock file needs manual removal."
#     486     ) from e
#     487 elif isinstance(e, ValueError):
# --> 488     raise OSError(f"{e}") from e
#     490 # Now we try to recover if we can find all files correctly in the cache
#     491 resolved_files = [
#     492     _get_cache_file_to_return(path_or_repo_id, filename, cache_dir, revision, repo_type)
#     493     for filename in full_filenames
#     494 ]
#
# OSError: Repo id must use alphanumeric chars, '-', '_' or '.'. The name cannot start or end with '-' or '.' and the maximum length is 96: './corn-vit-final'.

# %%
def transform(example):
    image = example["image"].convert("RGB")

    inputs = processor(
        image,
        return_tensors="pt"
    )

    example["pixel_values"] = inputs["pixel_values"][0]

    return example

dataset = dataset.with_transform(transform)

# %%
dataset = dataset.remove_columns(["image"])

# %%
dataset.set_format(
    type="torch",
    columns=["pixel_values", "label"]
)

# %%
model = ViTForImageClassification.from_pretrained(
    model_name,
    num_labels=len(labels),
    id2label=id2label,
    label2id=label2id,
    ignore_mismatched_sizes=True
)

# %%
training_args = TrainingArguments(
    output_dir="./corn-vit-model",
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    weight_decay=0.01,
    load_best_model_at_end=True,
    logging_steps=10,
    report_to="none",
    fp16=True
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"]
)

# %%
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))

# %%
trainer.train()

# %%
results = trainer.evaluate()

print(results)

# %%
trainer.save_model("./potato-vit-final")
processor.save_pretrained("./potato-vit-final")
